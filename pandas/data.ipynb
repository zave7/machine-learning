# %% [markdown]
# # 1. 시리즈

# %% [markdown]
# 시리즈 클래스는 1차원 배열의 값에 각 값에 대응되는 인덱스를 부여할 수 있는 구조를 갖고 있다.

# %%
import pandas as pd
sr = pd.Series([17000, 18000, 1000, 5000], index=["피자", "치킨", "콜라", "맥주"])
print(sr)
print(f"시리즈의 값 : {sr.values}")
print(f"시리즈의 인덱스 : {sr.index}")
# Out:
# 피자    17000
# 치킨    18000
# 콜라     1000
# 맥주     5000
# dtype: int64
# 시리즈의 값 : [17000 18000  1000  5000]
# 시리즈의 인덱스 : Index(['피자', '치킨', '콜라', '맥주'], dtype='object')

# %% [markdown]
# # 2. 데이터프레임

# %% [markdown]
# 데이터프레임은 2차원 리스트를 매개변수로 전달한다.  2차원이므로 행뱡향 인덱스(index)와 열방향 인덱스(column)가 존재한다.
# 다시 말해, 행과 열을 가지는 자료구조이다.

# %%
values = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
index = ['one', 'two', 'three']
columns = ['A', 'B', 'C']
df = pd.DataFrame(values, index=index, columns=columns)
print(df)
# Out:
#        A  B  C
# one    1  2  3
# two    4  5  6
# three  7  8  9

# %%
pwd
# Out:
# '/content/drive/MyDrive/colab/machine-learning/pandas'

# %%
# !git add -A
# !git commit -m "colab init"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@1b19f01f43d0.(none)')

# %%
# !git config --global user.email "if.zave@gmail.com"
# !git config --global user.name "zave7"

# %%
# !git add -A

# %%
# !git commit -m "init"
# Out:
# [main (root-commit) d7b34b5] init
#  1 file changed, 1 insertion(+)
#  create mode 100644 pandas/data.ipynb

# %%
# !git status
