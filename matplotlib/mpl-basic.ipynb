# %% [markdown]
# # 맷플롯립(Matplotlib)

# %% [markdown]
# 맷플롯립은 데이터를 차트(chart)나 플롯(plot)으로 시각화 하는 패키지이다.<br>
# 데이터 분석에서 Matplotlib은 데이터 분석 이전에 데이터 이해를 위한 시각화나, 데이터 분석 후에 결과를 시각화하기 위해서 사용된다.<br>

# %%
# Matplotlib의 주요 모듈인 pyplot를 관례상 'plt' 로 지정한다
import matplotlib.pyplot as plt 
# 폰트 매니저
import matplotlib.font_manager as fm
# 가능한 font list 확인
f = [f.name for f in fm.fontManager.ttflist]
print(f)
# 확인 이후
plt.rc('font', family='D2Coding')
# Out:
# ['cmsy10', 'STIXSizeThreeSym', 'STIXSizeFourSym', 'STIXNonUnicode', 'cmr10', 'DejaVu Sans Display', 'STIXGeneral', 'STIXGeneral', 'cmex10', 'cmss10', 'DejaVu Sans', 'STIXSizeTwoSym', 'DejaVu Serif', 'STIXSizeOneSym', 'DejaVu Sans Mono', 'STIXNonUnicode', 'DejaVu Sans', 'DejaVu Sans Mono', 'cmb10', 'DejaVu Sans Mono', 'STIXNonUnicode', 'STIXGeneral', 'DejaVu Sans', 'STIXSizeOneSym', 'DejaVu Serif Display', 'DejaVu Sans Mono', 'STIXSizeThreeSym', 'STIXSizeFourSym', 'STIXGeneral', 'STIXNonUnicode', 'cmmi10', 'STIXSizeTwoSym', 'DejaVu Serif', 'DejaVu Serif', 'STIXSizeFiveSym', 'DejaVu Sans', 'DejaVu Serif', 'cmtt10', 'Avenir Next Condensed', 'STIXNonUnicode', 'STIXIntegralsD', 'Noto Sans Lisu', 'Noto Sans Marchen', 'Brush Script MT', 'Times New Roman', 'Muna', 'Noto Sans PhagsPa', 'Arial Rounded MT Bold', 'Arial Narrow', 'Farah', 'Noto Nastaliq Urdu', '.SF Arabic', 'Euphemia UCAS', 'Noto Sans Kharoshthi', 'Noto Sans Pau Cin Hau', 'STIXIntegralsUpSm', 'Heiti TC', 'STIXIntegralsD', 'Basker
# ...

# %% [markdown]
# ### 1. 라인 플롯 그리기

# %% [markdown]
# plot()은 라인 플롯을 그리는 기능을 수행한다.<br>
# plot()에 x축과 y축의 값을 기재하고 그림을 표시하는 show()를 통해서 시각화한다.

# %%
plt.title("test")
plt.plot([1, 2, 3, 4], [2, 4, 8, 6])
plt.show()

# %% [markdown]
# ### 2. 축 레이블 삽입하기

# %% [markdown]
# x축과 y축 각각에 축 이름을 삽입하고 싶다면 xlabel('넣고 싶은 축이름')과 ylabel('넣고 싶은 축 이름')을 사용한다.

# %%
plt.title("test")
plt.plot([1, 2, 3, 4], [2, 4, 8, 6])
plt.xlabel('x축 이름')
plt.ylabel('y축 이름')
plt.show()

# %% [markdown]
# ### 3. 라인 추가와 범례 삽입하기

# %% [markdown]
# 다수의 plot()을 하나의 그래프에 나타낼 수 있다.<br>
# 여러개의 라인 플롯을 동시에 사용할 경우에는 각 선이 어떤 데이터를 나타내는지를 보여주기 위해 범례(legned)를 사용할 수 있다.

# %%
plt.title("student")
plt.plot([1, 2, 3, 4], [2, 4, 8, 6])
plt.plot([1.5, 2.5, 3.5, 4.5], [3, 5, 8, 10]) # 라인 새로 추가
plt.xlabel("hours")
plt.ylabel("score")
plt.legend(["A student", "B student"]) # 범례 삽입
plt.show()
